# %% [markdown]
# # Data Gathering
#
# Mengambil data dari kaggle, mengunduh dengan API. Yang pertama install kaggle dahulu.

# %%
## ambil API dari kaggle
pip install kaggle

# %% [markdown]
# # Unduh dataset dari kaggle

# %%
# !kaggle datasets download shreyanshkhandelwal/goal-dataset-top-5-european-leagues
# Out:
# ...
#   0%|          | 0.00/174k [00:00<?, ?B/s]
# 100%|██████████| 174k/174k [00:00<00:00, 4.14MB/s]

# %%
# memuat data dengan pandas dan np

import pandas as pd
import numpy as np

path = "epl-goalScorer(20-21).csv"

df = pd.read_csv(path)
df
# Out:
#      Unnamed: 0    id             player_name  games  time  goals         xG  \
# 0             0   647              Harry Kane     35  3097     23  22.174859
# 1             1  1250           Mohamed Salah     37  3085     22  20.250847
# 2             2  1228         Bruno Fernandes     37  3117     18  16.019454
# 3             3   453           Son Heung-Min     37  3139     17  11.023287
# 4             4   822         Patrick Bamford     38  3085     17  18.401863
# ..          ...   ...                     ...    ...   ...    ...        ...
# 517         517  9415  Jaden Philogene-Bidace      1     1      0   0.000000
# 518         518  9423         Gaetano Berardi      2   113      0   0.074761
# 519         519  9524          Anthony Elanga      1    67      0   0.000000
# 520         520  9540             Femi Seriki      1     1      0   0.000000
# 521         521  9552         Tyrese Francois      1    13      0   0.000000
#
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0    id            player_name  games  time  goals         xG  \
# 0           0   647             Harry Kane     35  3097     23  22.174859
# 1           1  1250          Mohamed Salah     37  3085     22  20.250847
# 2           2  1228        Bruno Fernandes     37  3117     18  16.019454
# 3           3   453          Son Heung-Min     37  3139     17  11.023287
# 4           4   822        Patrick Bamford     38  3085     17  18.401863
# 5           5  5555  Dominic Calvert-Lewin     32  2788     16  18.136449
# 6           6   755            Jamie Vardy     34  2848     15  19.942946
# 7           7  8865          Ollie Watkins     37  3330     14  16.280178
# 8           8   314         Ilkay Gündogan     28  2033     13   9.566883
# 9           9  3277    Alexandre Lacazette     30  1928     13  12.028909
#
#    assists         xA  shots  key_passes  yellow_cards  red_cards position  \
# 0       14   7.577094    138          49             1          0        F
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# id                int64
# player_name      object
# games             int64
# time              int64
# goals             int64
# xG              float64
# assists           int64
# xA              float64
# shots             int64
# key_passes        int64
# yellow_cards      int64
# red_cards         int64
# position         object
# team_title       object
# npg               int64
# npxG            float64
# xGChain         float64
# xGBuildup       float64
# dtype: object

# %%
df.tail()
# Out:
#      Unnamed: 0    id             player_name  games  time  goals        xG  \
# 517         517  9415  Jaden Philogene-Bidace      1     1      0  0.000000
# 518         518  9423         Gaetano Berardi      2   113      0  0.074761
# 519         519  9524          Anthony Elanga      1    67      0  0.000000
# 520         520  9540             Femi Seriki      1     1      0  0.000000
# 521         521  9552         Tyrese Francois      1    13      0  0.000000
#
#      assists   xA  shots  key_passes  yellow_cards  red_cards position  \
# 517        0  0.0      0           0             0          0        S
# 518        0  0.0      1           0             0          0      D S
# 519        0  0.0      0           0             0          0        M
# 520        0  0.0      0           0             0          0        S
# 521        0  0.0      0           0             0          0        S
#
#             team_title  npg      npxG   xGChain  xGBuildup
# ...

# %%
df_noid = df.iloc[:,2:]
df_noid
# Out:
#                 player_name  games  time  goals         xG  assists  \
# 0                Harry Kane     35  3097     23  22.174859       14
# 1             Mohamed Salah     37  3085     22  20.250847        5
# 2           Bruno Fernandes     37  3117     18  16.019454       12
# 3             Son Heung-Min     37  3139     17  11.023287       10
# 4           Patrick Bamford     38  3085     17  18.401863        7
# ..                      ...    ...   ...    ...        ...      ...
# 517  Jaden Philogene-Bidace      1     1      0   0.000000        0
# 518         Gaetano Berardi      2   113      0   0.074761        0
# 519          Anthony Elanga      1    67      0   0.000000        0
# 520             Femi Seriki      1     1      0   0.000000        0
# 521         Tyrese Francois      1    13      0   0.000000        0
#
#             xA  shots  key_passes  yellow_cards  red_cards position  \
# 0     7.577094    138          49             1          0        F
# ...

# %%
df_ascendName = df_noid.sort_values(by = 'player_name', ascending=True)

df_ascendName.head(15)
# Out:
#                 player_name  games  time  goals        xG  assists        xA  \
# 154          Aaron Connolly     16   755      2  4.412464        1  0.149897
# 281         Aaron Cresswell     35  3086      0  0.883464        8  7.347331
# 390          Aaron Ramsdale     37  3330      0  0.000000        0  0.053571
# 139       Aaron Wan-Bissaka     34  3060      2  0.932454        4  2.547663
# 126      Abdoulaye Doucouré     28  2409      2  2.369523        3  2.381616
# 380        Aboubakar Kamara     11   303      0  0.654920        0  0.328969
# 163            Adam Lallana     29  1528      1  1.614306        1  2.628758
# 242            Adam Webster     28  2506      1  1.272957        0  0.253216
# 119            Adama Traoré     36  2604      2  1.995262        2  5.228081
# 75          Ademola Lookman     34  2765      4  6.251116        4  5.258407
# 278                  Adrián      3   270      0  0.000000        0  0.000000
# ...

# %%
df_ascendAssist = df_ascendName.sort_values(["assists"], ascending=False)

df_ascendAssist.head(15)
# Out:
#                 player_name  games  time  goals         xG  assists  \
# 0                Harry Kane     35  3097     23  22.174859       14
# 2           Bruno Fernandes     37  3117     18  16.019454       12
# 58          Kevin De Bruyne     24  1918      5   9.908440       11
# 3             Son Heung-Min     37  3139     17  11.023287       10
# 51            Jack Grealish     26  2187      6   5.192684       10
# 57                 Raphinha     30  2369      6   6.219143        9
# 6               Jamie Vardy     34  2848     15  19.942946        9
# 15          Marcus Rashford     37  2941     11   9.579710        9
# 281         Aaron Cresswell     35  3086      0   0.883464        8
# 41            Jack Harrison     36  2871      8   6.254043        8
# 83              Pascal Groß     33  2379      3   5.010526        8
# 49              Timo Werner     35  2605      6  13.432796        8
# 16               Sadio Mané     35  2805     11  14.828548        7
# ...

# %%
df_noid.describe(include='all')
# Out:
#        player_name       games         time       goals          xG  \
# count          522  522.000000   522.000000  522.000000  522.000000
# unique         522         NaN          NaN         NaN         NaN
# top     Harry Kane         NaN          NaN         NaN         NaN
# freq             1         NaN          NaN         NaN         NaN
# mean           NaN   19.643678  1420.068966    1.862069    2.000806
# std            NaN   11.619836  1031.604819    3.338851    3.317946
# min            NaN    1.000000     1.000000    0.000000    0.000000
# 25%            NaN   10.000000   470.250000    0.000000    0.074668
# 50%            NaN   21.000000  1342.000000    1.000000    0.737295
# 75%            NaN   30.000000  2319.000000    2.000000    2.053378
# max            NaN   38.000000  3420.000000   23.000000   22.174859
#
#            assists          xA       shots  key_passes  yellow_cards  \
# count   522.000000  522.000000  522.000000  522.000000    522.000000
# ...

# %%
df_ascendAssist[['goals','games','assists','shots']].mean()
# Out:
# goals       1.862069
# games      19.643678
# assists     1.289272
# shots      17.379310
# dtype: float64

# %%
df_ascendName[['team_title']].mode()
# Out:
#              team_title
# 0               Everton
# 1  West Bromwich Albion

# %%
df_ascendAssist = df_ascendName.sort_values(["team_title"], ascending=False)

df_ascendAssist.head(15)
